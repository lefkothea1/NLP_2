# %% [markdown]
# <a href="https://colab.research.google.com/github/lefkothea1/NLP_2/blob/Milena/Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instal at every runtime?-prob yes
# !pip install checklist
# !pip install torch

#should i install it every time?-yes
# !pip install simpletransformers 

from simpletransformers.classification import ClassificationModel, ClassificationArgs
# Out:
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
#       Successfully uninstalled google-auth-1.4.2
# ...

# %%
# from platform import python_version #to check version
# python_version()

import pandas as pd
import checklist
import spacy 
from checklist.perturb import Perturb
#from checklist.perturb import add_negation
import nltk #; nltk.download('omw-1.4')
#nltk.download()

# %%
# stolen from E6
#setting up google drive and loading diagnostic test data
#from google.colab import drive
#drive.mount('/content/drive')
data = pd.read_csv("C:/Users/milen/Desktop/NLP Technology/NLP_2/data/Assignment 2_IntrotoNLP2022_data/olid-subset-diagnostic-tests.csv")

#$loading eng
nlp = spacy.load("en_core_web_sm")

# %%
#loading finetuned MODEL FROM DRIVE
bert_mod = ClassificationModel("bert", "C:/Users/milen/Desktop/NLP Technology/NLP_2/trained_models2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\transformers\configuration_utils.py:596, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     594 try:
#     595     # Load from URL or cache if already cached
# --> 596     resolved_config_file = cached_path(
#     597         config_file,
#     598         cache_dir=cache_dir,
#     599         force_download=force_download,
#     600         proxies=proxies,
#     601         resume_download=resume_download,
#     602         local_files_only=local_files_only,
#     603         use_auth_token=use_auth_token,
#     604         user_agent=user_agent,
#     605     )
#     607 except RepositoryNotFoundError:
#
# ...
